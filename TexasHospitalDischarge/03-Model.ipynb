# %% [markdown]
# ##Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

from scipy import stats
import yaml, time, sys, os, glob

import seaborn as sns
sns.set_style("darkgrid")

from IPython.display import display, Markdown
pd.set_option('display.max_columns', None)  

DATASET = "Texas_Inpatient_Discharge"
SPLIT_TRAINING = True
DEBUG = False
SEED = 42

COLAB = 'google.colab' in sys.modules
if COLAB:
    ROOT = f"/content/gdrive/MyDrive/datasets/{DATASET.replace(' ','_')}/"
else:
    ROOT = "./"

# %%
if COLAB:
  from google.colab import drive
  if not os.path.isdir("/content/gdrive"):
    drive.mount("/content/gdrive")
    d = "/content/gdrive/MyDrive/datasets"
    if not os.path.isdir(d): os.makedirs(d)
  if not os.path.isdir(ROOT): os.makedirs(ROOT)

# %% [markdown]
# ##Dataset

# %%
df = pd.read_pickle(f"{ROOT}/data/df_train_sample_00_of_1_clean.pkl")
print(df.shape)
df.head()
# Out:
# (99969, 195)
#            RECORD_ID DISCHARGE THCIC_ID                         PROVIDER_NAME  \
# 884115  320136748870    2013Q3   838400  Memorial Hermann Rehab Hospital Katy
# 33602   120130546450    2013Q1   409000             John Peter Smith Hospital
# 31627   420135644393    2013Q4   286000               Mother Frances Hospital
# 112206  120137773390    2013Q1   076000       Tomball Regional Medical Center
# 71288   420131237653    2013Q4   725400  Mother Frances Hospital-Jacksonville
#
#        TYPE_OF_ADMISSION       SOURCE_OF_ADMISSION SPEC_UNIT_1 SPEC_UNIT_2  \
# 884115          Elective  Transfer from a hospital           R         NaN
# 33602          Emergency   Non-healthcare Facility           I         NaN
# 31627          Emergency   Non-healthcare Facility         NaN         NaN
# 112206         Emergency   Non-healthcare Facility           I         NaN
# 71288          Emergency   Non-healthcare Facility         NaN         NaN
#
#        SPEC_UNIT_3 SPEC_UNIT_4 SPEC_UNIT_5 PAT_STATE PAT_ZIP PAT_COUNTRY  \
# 884115         NaN         NaN         NaN     Texas   77095          US
# 33602          NaN         NaN         NaN     Texas   76008          US
# 31627          NaN         NaN         NaN     Texas   75701          US
# 112206         NaN         NaN         NaN     Texas   77429          US
# 71288          NaN         NaN         NaN     Texas   75766          US
#
#        COUNTY PUBLIC_HEALTH_REGION PAT_STATUS SEX_CODE   RACE  \
# 884115    201                   06         07   Female  White
# 33602     367                   03         01     Male  Other
# 31627     423                   04         01     Male  Other
# 112206    201                   06         01   Female  White
# 71288     073                   04         01   Female  Other
#
#               ETHNICITY ADMIT_WEEKDAY  LENGTH_OF_STAY PAT_AGE  \
# 884115  Not of Hispanic             2               1      20
# 33602   Hispanic Origin             2               2      13
# 31627   Hispanic Origin             5               2      15
# 112206  Not of Hispanic             1               4      17
# 71288   Hispanic Origin             6               1      04
#
#        FIRST_PAYMENT_SRC SECONDARY_PAYMENT_SRC TYPE_OF_BILL TOTAL_CHARGES  \
# 884115                MA                    MB          111       1671.00
# 33602                 MA                   NaN          111      53064.01
# 31627                 BL                   NaN          111      17545.00
# 112206                13                    ZZ          111      36668.56
# 71288                 ZZ                   NaN          111      38984.47
#
#        TOTAL_NON_COV_CHARGES TOTAL_CHARGES_ACCOMM  \
# 884115                  0.00              1145.00
# 33602                   0.00              4092.00
# 31627                   0.00              1922.00
# 112206                  0.00              8940.00
# 71288                   0.00               923.00
#
#        TOTAL_NON_COV_CHARGES_ACCOMM TOTAL_CHARGES_ANCIL  \
# 884115                         0.00              526.00
# 33602                          0.00            48972.01
# 31627                          0.00            15623.00
# 112206                         0.00            27728.56
# 71288                          0.00            38061.47
#
#        TOTAL_NON_COV_CHARGES_ANCIL POA_PROVIDER_INDICATOR ADMITTING_DIAGNOSIS  \
# 884115                        0.00                      X               V5789
# 33602                         0.00                      M               78650
# 31627                         0.00                      R                 486
# 112206                        0.00                      M                7802
# 71288                         0.00                      X                5409
#
#        PRINC_DIAG_CODE POA_PRINC_DIAG_CODE OTH_DIAG_CODE_1  \
# 884115           V5789                 NaN            1919
# 33602            41401                   Y           42822
# 31627              486                   Y            4019
# 112206            7802                   Y            5849
# 71288             5409                   Y             NaN
#
#        POA_OTH_DIAG_CODE_1 OTH_DIAG_CODE_2 POA_OTH_DIAG_CODE_2  \
# 884115                   Y            5119                   Y
# 33602                    Y            4280                   Y
# 31627                    Y             NaN                 NaN
# 112206                   Y           25080                   Y
# 71288                  NaN             NaN                 NaN
#
#        OTH_DIAG_CODE_3 POA_OTH_DIAG_CODE_3 OTH_DIAG_CODE_4  \
# 884115           V8543                 NaN           78459
# 33602              496                   Y            4139
# 31627              NaN                 NaN             NaN
# 112206            2761                   Y           42731
# 71288              NaN                 NaN             NaN
#
#        POA_OTH_DIAG_CODE_4 OTH_DIAG_CODE_5 POA_OTH_DIAG_CODE_5  \
# 884115                   Y           27801                   Y
# 33602                    Y            4019                   Y
# 31627                  NaN             NaN                 NaN
# 112206                   Y            2768                   Y
# 71288                  NaN             NaN                 NaN
#
#        OTH_DIAG_CODE_6 POA_OTH_DIAG_CODE_6 OTH_DIAG_CODE_7  \
# 884115            7812                   Y            5180
# 33602             2720                   Y           25000
# 31627              NaN                 NaN             NaN
# 112206           42789                   Y            4019
# 71288              NaN                 NaN             NaN
#
#        POA_OTH_DIAG_CODE_7 OTH_DIAG_CODE_8 POA_OTH_DIAG_CODE_8  \
# 884115                   Y           34590                   Y
# 33602                    Y            4148                   Y
# 31627                  NaN             NaN                 NaN
# 112206                   Y            2809                   Y
# 71288                  NaN             NaN                 NaN
#
#        OTH_DIAG_CODE_9 POA_OTH_DIAG_CODE_9 OTH_DIAG_CODE_10  \
# 884115            4019                   Y             7993
# 33602            V4502                 NaN            V4581
# 31627              NaN                 NaN              NaN
# 112206            5589                   Y             2724
# 71288              NaN                 NaN              NaN
#
#        POA_OTH_DIAG_CODE_10 OTH_DIAG_CODE_11 POA_OTH_DIAG_CODE_11  \
# 884115                    Y             2724                    Y
# 33602                   NaN              311                    Y
# 31627                   NaN              NaN                  NaN
# 112206                    Y            42611                    Y
# 71288                   NaN              NaN                  NaN
#
#        OTH_DIAG_CODE_12 POA_OTH_DIAG_CODE_12 OTH_DIAG_CODE_13  \
# 884115            72887                    Y            36250
# 33602             30002                    Y              NaN
# 31627               NaN                  NaN              NaN
# 112206            49390                    Y            V1588
# 71288               NaN                  NaN              NaN
#
#        POA_OTH_DIAG_CODE_13 OTH_DIAG_CODE_14 POA_OTH_DIAG_CODE_14  \
# 884115                    Y            78093                    Y
# 33602                   NaN              NaN                  NaN
# 31627                   NaN              NaN                  NaN
# 112206                  NaN             7802                  NaN
# 71288                   NaN              NaN                  NaN
#
#        OTH_DIAG_CODE_15 POA_OTH_DIAG_CODE_15 OTH_DIAG_CODE_16  \
# 884115            36901                    Y            V5878
# 33602               NaN                  NaN              NaN
# 31627               NaN                  NaN              NaN
# 112206              NaN                  NaN              NaN
# 71288               NaN                  NaN              NaN
#
#        POA_OTH_DIAG_CODE_16 OTH_DIAG_CODE_17 POA_OTH_DIAG_CODE_17  \
# 884115                  NaN              NaN                  NaN
# 33602                   NaN              NaN                  NaN
# 31627                   NaN              NaN                  NaN
# 112206                  NaN              NaN                  NaN
# 71288                   NaN              NaN                  NaN
#
#        OTH_DIAG_CODE_18 POA_OTH_DIAG_CODE_18 OTH_DIAG_CODE_19  \
# 884115              NaN                  NaN              NaN
# 33602               NaN                  NaN              NaN
# 31627               NaN                  NaN              NaN
# 112206              NaN                  NaN              NaN
# 71288               NaN                  NaN              NaN
#
#        POA_OTH_DIAG_CODE_19 OTH_DIAG_CODE_20 POA_OTH_DIAG_CODE_20  \
# 884115                  NaN              NaN                  NaN
# 33602                   NaN              NaN                  NaN
# 31627                   NaN              NaN                  NaN
# 112206                  NaN              NaN                  NaN
# 71288                   NaN              NaN                  NaN
#
#        OTH_DIAG_CODE_21 POA_OTH_DIAG_CODE_21 OTH_DIAG_CODE_22  \
# 884115              NaN                  NaN              NaN
# 33602               NaN                  NaN              NaN
# 31627               NaN                  NaN              NaN
# 112206              NaN                  NaN              NaN
# 71288               NaN                  NaN              NaN
#
#        POA_OTH_DIAG_CODE_22 OTH_DIAG_CODE_23 POA_OTH_DIAG_CODE_23  \
# 884115                  NaN              NaN                  NaN
# 33602                   NaN              NaN                  NaN
# 31627                   NaN              NaN                  NaN
# 112206                  NaN              NaN                  NaN
# 71288                   NaN              NaN                  NaN
#
#        OTH_DIAG_CODE_24 POA_OTH_DIAG_CODE_24 E_CODE_1 POA_E_CODE_1 E_CODE_2  \
# 884115              NaN                  NaN      NaN          NaN      NaN
# 33602               NaN                  NaN      NaN          NaN      NaN
# 31627               NaN                  NaN      NaN          NaN      NaN
# 112206              NaN                  NaN    E9426            Y    E9413
# 71288               NaN                  NaN      NaN          NaN      NaN
#
#        POA_E_CODE_2 E_CODE_3 POA_E_CODE_3 E_CODE_4 POA_E_CODE_4 E_CODE_5  \
# 884115          NaN      NaN          NaN      NaN          NaN      NaN
# 33602           NaN      NaN          NaN      NaN          NaN      NaN
# 31627           NaN      NaN          NaN      NaN          NaN      NaN
# 112206            Y    E9420            Y    E9443            Y    E9444
# 71288           NaN      NaN          NaN      NaN          NaN      NaN
#
#        POA_E_CODE_5 E_CODE_6 POA_E_CODE_6 E_CODE_7 POA_E_CODE_7 E_CODE_8  \
# 884115          NaN      NaN          NaN      NaN          NaN      NaN
# 33602           NaN      NaN          NaN      NaN          NaN      NaN
# 31627           NaN      NaN          NaN      NaN          NaN      NaN
# 112206            Y      NaN          NaN      NaN          NaN      NaN
# 71288           NaN      NaN          NaN      NaN          NaN      NaN
#
#        POA_E_CODE_8 E_CODE_9 POA_E_CODE_9 E_CODE_10 POA_E_CODE_10  \
# 884115          NaN      NaN          NaN       NaN           NaN
# 33602           NaN      NaN          NaN       NaN           NaN
# 31627           NaN      NaN          NaN       NaN           NaN
# 112206          NaN      NaN          NaN       NaN           NaN
# 71288           NaN      NaN          NaN       NaN           NaN
#
#        PRINC_SURG_PROC_CODE PRINC_SURG_PROC_DAY PRINC_ICD9_CODE  \
# 884115                  NaN                 NaN             NaN
# 33602                  3722                +001            3722
# 31627                   NaN                 NaN             NaN
# 112206                  NaN                 NaN             NaN
# 71288                  4701                +000            4701
#
#        OTH_SURG_PROC_CODE_1 OTH_SURG_PROC_DAY_1 OTH_ICD9_CODE_1  \
# 884115                  NaN                 NaN             NaN
# 33602                  0066                +001            0066
# 31627                   NaN                 NaN             NaN
# 112206                  NaN                 NaN             NaN
# 71288                   NaN                 NaN             NaN
#
#        OTH_SURG_PROC_CODE_2 OTH_SURG_PROC_DAY_2 OTH_ICD9_CODE_2  \
# 884115                  NaN                 NaN             NaN
# 33602                  3607                +001            3607
# 31627                   NaN                 NaN             NaN
# 112206                  NaN                 NaN             NaN
# 71288                   NaN                 NaN             NaN
#
#        OTH_SURG_PROC_CODE_3 OTH_SURG_PROC_DAY_3 OTH_ICD9_CODE_3  \
# 884115                  NaN                 NaN             NaN
# 33602                  8856                +001            8856
# 31627                   NaN                 NaN             NaN
# 112206                  NaN                 NaN             NaN
# 71288                   NaN                 NaN             NaN
#
#        OTH_SURG_PROC_CODE_4 OTH_SURG_PROC_DAY_4 OTH_ICD9_CODE_4  \
# 884115                  NaN                 NaN             NaN
# 33602                  8853                +001            8853
# 31627                   NaN                 NaN             NaN
# 112206                  NaN                 NaN             NaN
# 71288                   NaN                 NaN             NaN
#
#        OTH_SURG_PROC_CODE_5 OTH_SURG_PROC_DAY_5 OTH_ICD9_CODE_5  \
# 884115                  NaN                 NaN             NaN
# 33602                  0045                +001            0045
# 31627                   NaN                 NaN             NaN
# 112206                  NaN                 NaN             NaN
# 71288                   NaN                 NaN             NaN
#
#        OTH_SURG_PROC_CODE_6 OTH_SURG_PROC_DAY_6 OTH_ICD9_CODE_6  \
# 884115                  NaN                 NaN             NaN
# 33602                  0040                +001            0040
# 31627                   NaN                 NaN             NaN
# 112206                  NaN                 NaN             NaN
# 71288                   NaN                 NaN             NaN
#
#        OTH_SURG_PROC_CODE_7 OTH_SURG_PROC_DAY_7 OTH_ICD9_CODE_7  \
# 884115                  NaN                 NaN             NaN
# 33602                   NaN                 NaN             NaN
# 31627                   NaN                 NaN             NaN
# 112206                  NaN                 NaN             NaN
# 71288                   NaN                 NaN             NaN
#
#        OTH_SURG_PROC_CODE_8 OTH_SURG_PROC_DAY_8 OTH_ICD9_CODE_8  \
# 884115                  NaN                 NaN             NaN
# 33602                   NaN                 NaN             NaN
# 31627                   NaN                 NaN             NaN
# 112206                  NaN                 NaN             NaN
# 71288                   NaN                 NaN             NaN
#
#        OTH_SURG_PROC_CODE_9 OTH_SURG_PROC_DAY_9 OTH_ICD9_CODE_9  \
# 884115                  NaN                 NaN             NaN
# 33602                   NaN                 NaN             NaN
# 31627                   NaN                 NaN             NaN
# 112206                  NaN                 NaN             NaN
# 71288                   NaN                 NaN             NaN
#
#        OTH_SURG_PROC_CODE_10 OTH_SURG_PROC_DAY_10 OTH_ICD9_CODE_10  \
# 884115                   NaN                  NaN              NaN
# 33602                    NaN                  NaN              NaN
# 31627                    NaN                  NaN              NaN
# 112206                   NaN                  NaN              NaN
# 71288                    NaN                  NaN              NaN
#
#        OTH_SURG_PROC_CODE_11 OTH_SURG_PROC_DAY_11 OTH_ICD9_CODE_11  \
# 884115                   NaN                  NaN              NaN
# 33602                    NaN                  NaN              NaN
# 31627                    NaN                  NaN              NaN
# 112206                   NaN                  NaN              NaN
# 71288                    NaN                  NaN              NaN
#
#        OTH_SURG_PROC_CODE_12 OTH_SURG_PROC_DAY_12 OTH_ICD9_CODE_12  \
# 884115                   NaN                  NaN              NaN
# 33602                    NaN                  NaN              NaN
# 31627                    NaN                  NaN              NaN
# 112206                   NaN                  NaN              NaN
# 71288                    NaN                  NaN              NaN
#
#        OTH_SURG_PROC_CODE_13 OTH_SURG_PROC_DAY_13 OTH_ICD9_CODE_13  \
# 884115                   NaN                  NaN              NaN
# 33602                    NaN                  NaN              NaN
# 31627                    NaN                  NaN              NaN
# 112206                   NaN                  NaN              NaN
# 71288                    NaN                  NaN              NaN
#
#        OTH_SURG_PROC_CODE_14 OTH_SURG_PROC_DAY_14 OTH_ICD9_CODE_14  \
# 884115                   NaN                  NaN              NaN
# 33602                    NaN                  NaN              NaN
# 31627                    NaN                  NaN              NaN
# 112206                   NaN                  NaN              NaN
# 71288                    NaN                  NaN              NaN
#
#        OTH_SURG_PROC_CODE_15 OTH_SURG_PROC_DAY_15 OTH_ICD9_CODE_15  \
# 884115                   NaN                  NaN              NaN
# 33602                    NaN                  NaN              NaN
# 31627                    NaN                  NaN              NaN
# 112206                   NaN                  NaN              NaN
# 71288                    NaN                  NaN              NaN
#
#        OTH_SURG_PROC_CODE_16 OTH_SURG_PROC_DAY_16 OTH_ICD9_CODE_16  \
# 884115                   NaN                  NaN              NaN
# 33602                    NaN                  NaN              NaN
# 31627                    NaN                  NaN              NaN
# 112206                   NaN                  NaN              NaN
# 71288                    NaN                  NaN              NaN
#
#        OTH_SURG_PROC_CODE_17 OTH_SURG_PROC_DAY_17 OTH_ICD9_CODE_17  \
# 884115                   NaN                  NaN              NaN
# 33602                    NaN                  NaN              NaN
# 31627                    NaN                  NaN              NaN
# 112206                   NaN                  NaN              NaN
# 71288                    NaN                  NaN              NaN
#
#        OTH_SURG_PROC_CODE_18 OTH_SURG_PROC_DAY_18 OTH_ICD9_CODE_18  \
# 884115                   NaN                  NaN              NaN
# 33602                    NaN                  NaN              NaN
# 31627                    NaN                  NaN              NaN
# 112206                   NaN                  NaN              NaN
# 71288                    NaN                  NaN              NaN
#
#        OTH_SURG_PROC_CODE_19 OTH_SURG_PROC_DAY_19 OTH_ICD9_CODE_19  \
# 884115                   NaN                  NaN              NaN
# 33602                    NaN                  NaN              NaN
# 31627                    NaN                  NaN              NaN
# 112206                   NaN                  NaN              NaN
# 71288                    NaN                  NaN              NaN
#
#        OTH_SURG_PROC_CODE_20 OTH_SURG_PROC_DAY_20 OTH_ICD9_CODE_20  \
# 884115                   NaN                  NaN              NaN
# 33602                    NaN                  NaN              NaN
# 31627                    NaN                  NaN              NaN
# 112206                   NaN                  NaN              NaN
# 71288                    NaN                  NaN              NaN
#
#        OTH_SURG_PROC_CODE_21 OTH_SURG_PROC_DAY_21 OTH_ICD9_CODE_21  \
# 884115                   NaN                  NaN              NaN
# 33602                    NaN                  NaN              NaN
# 31627                    NaN                  NaN              NaN
# 112206                   NaN                  NaN              NaN
# 71288                    NaN                  NaN              NaN
#
#        OTH_SURG_PROC_CODE_22 OTH_SURG_PROC_DAY_22 OTH_ICD9_CODE_22  \
# 884115                   NaN                  NaN              NaN
# 33602                    NaN                  NaN              NaN
# 31627                    NaN                  NaN              NaN
# 112206                   NaN                  NaN              NaN
# 71288                    NaN                  NaN              NaN
#
#        OTH_SURG_PROC_CODE_23 OTH_SURG_PROC_DAY_23 OTH_ICD9_CODE_23  \
# 884115                   NaN                  NaN              NaN
# 33602                    NaN                  NaN              NaN
# 31627                    NaN                  NaN              NaN
# 112206                   NaN                  NaN              NaN
# 71288                    NaN                  NaN              NaN
#
#        OTH_SURG_PROC_CODE_24 OTH_SURG_PROC_DAY_24 OTH_ICD9_CODE_24 MS_MDC  \
# 884115                   NaN                  NaN              NaN     23
# 33602                    NaN                  NaN              NaN     05
# 31627                    NaN                  NaN              NaN     04
# 112206                   NaN                  NaN              NaN     05
# 71288                    NaN                  NaN              NaN     06
#
#        MS_DRG MS_GROUPER_VERSION_NBR MS_GROUPER_ERROR_CODE APR_MDC APR_DRG  \
# 884115    945                  01300                    00      23     860
# 33602     247                  01300                    00      05     175
# 31627     195                  01300                    00      04     139
# 112206    312                  01300                    00      05     204
# 71288     343                  01300                    00      06     225
#
#        RISK_MORTALITY ILLNESS_SEVERITY APR_GROUPER_VERSION_NBR  \
# 884115              2                3                   07300
# 33602               2                2                   07300
# 31627               1                1                   07300
# 112206              3                3                   07300
# 71288               1                1                   07300
#
#        APR_GROUPER_ERROR_CODE ATTENDING_PHYSICIAN_UNIF_ID  \
# 884115                     00                  1229763162
# 33602                      00                  1578252829
# 31627                      00                  2348600662
# 112206                     00                  9999999998
# 71288                      00                  9999999998
#
#        OPERATING_PHYSICIAN_UNIF_ID ENCOUNTER_INDICATOR CERT_STATUS  \
# 884115                         NaN                  01           1
# 33602                   1578252829                  01           2
# 31627                          NaN                  01           1
# 112206                         NaN                  01           6
# 71288                   9999999998                  01           1
#
#        FILLER_SPACE  TARGET
# 884115          NaN   short
# 33602           NaN   short
# 31627           NaN   short
# 112206          NaN  medium
# 71288           NaN   short

# %% [markdown]
# ##Model Building

# %%
target = "TARGET"
cat_features = ["TYPE_OF_ADMISSION","SOURCE_OF_ADMISSION","PAT_STATE", "RACE"]
num_features = []

features = cat_features + num_features

print(f"{cat_features}")
print(f"{num_features}")
print(f"{features}")
# Out:
# ['TYPE_OF_ADMISSION', 'SOURCE_OF_ADMISSION', 'PAT_STATE', 'RACE']
# []
# ['TYPE_OF_ADMISSION', 'SOURCE_OF_ADMISSION', 'PAT_STATE', 'RACE']

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.feature_selection import chi2, SelectPercentile

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import classification_report, accuracy_score, recall_score

# %%
cat_preprocessor = Pipeline(steps=[
    ('imput', SimpleImputer(strategy='most_frequent')),
    ('encode', OneHotEncoder(handle_unknown='ignore')),
    ('select', SelectPercentile(chi2, percentile=80)),
])

num_preprocessor = Pipeline(steps=[
    ('imput', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler()),
])

preprocessor = ColumnTransformer(transformers=[
    ('cat', cat_preprocessor, cat_features),
    ('num', num_preprocessor, num_features),
])

model = Pipeline(steps=[
    ('pre', preprocessor),
    ('clf', RandomForestClassifier()),
])

# %%
x = df[features]
y = df[target]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,stratify=y,test_size=0.4,random_state=SEED)
x_train.shape, x_test.shape
# Out:
# ((59981, 4), (39988, 4))

# %%
model.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('imput',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encode',
#                                                                    OneHotEncoder(handle_unknown='ignore')),
#                                                                   ('select',
#                                                                    SelectPercentile(percentile=80,
#                                                                                     score_func=<function chi2 at 0x7fa43c96e8c0>))]),
#                                                   ['TYPE_OF_ADMISSION',
#                                                    'SOURCE_OF_ADMISSION',
#                                                    'PAT_STATE', 'RACE']),
#                                                  ('num',
#                                                   Pipeline(steps=[('imput',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   [])])),
#                 ('clf', RandomForestClassifier())])

# %%
y_pred = model.predict(x_test)

# %%
print(classification_report(y_test,y_pred,digits=4))
# Out:
#               precision    recall  f1-score   support
#
#         long     0.6183    0.2321    0.3375      8017
#       medium     0.4332    0.6508    0.5201     15319
#        short     0.5615    0.4709    0.5122     16652
#
#     accuracy                         0.4919     39988
#    macro avg     0.5377    0.4513    0.4566     39988
# weighted avg     0.5237    0.4919    0.4802     39988

# %%
import my_lib as my
my.make_assignment()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-187e819543c3> in <cell line: 2>()
#       1 import my_lib as my
# ----> 2 my.make_assignment()
#
# AttributeError: module 'my_lib' has no attribute 'make_assignment'
